# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import homogeneity_completeness_v_measure

import matplotlib.pyplot as plt
import numpy as np

datasets = load_iris()

X,y = datasets.data,datasets.target

clus = KMeans(n_clusters=3)
y_p = clus.fit_predict(X)

h,c,v = homogeneity_completeness_v_measure(y,y_p)

print('homogeneity :',h)
print('completeness :',c)
print('v-measure:',v)

X_t = np.transpose(X)
plt.subplot(1,2,1)
plt.scatter(X_t[0],X_t[1],c=y)
plt.subplot(1,2,2)
plt.scatter(X_t[0],X_t[1],c=y_p)
plt.show()
# Out:
# homogeneity : 0.7514854021988338
# completeness : 0.7649861514489815
# v-measure: 0.7581756800057784
